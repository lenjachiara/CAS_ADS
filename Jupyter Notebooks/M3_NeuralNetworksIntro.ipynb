# %% [markdown]
# <a href="https://colab.research.google.com/github/neworldemancer/DSF5/blob/master/Course_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to machine learning & Data Analysis
#
# Basic introduction on how to perform typical machine learning tasks with Python.
#
# Prepared by Mykhailo Vladymyrov & Aris Marcolongo,
# Data Science Lab, University Of Bern, 2023
#
# This work is licensed under <a href="https://creativecommons.org/share-your-work/public-domain/cc0/">CC0</a>.
#
# # Part 4.

# %% [markdown]
# # 0. Load libraries

# %%
from matplotlib import  pyplot as plt
import numpy as np
from imageio import imread
import pandas as pd
from time import time as timer

import tensorflow as tf
import plotly.graph_objects as go

# %matplotlib inline
from PIL import Image
from matplotlib import animation
from matplotlib import cm
from IPython.display import HTML
from sklearn.datasets import make_blobs

plt.rcParams["animation.html"] = "jshtml"  # for matplotlib 2.1 and above, uses JavaScript
# Out:
# 2023-09-29 09:01:48.410477: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import os
import tarfile

# %%
if not os.path.exists('data'):
    path = os.path.abspath('.')+'/colab_material.tgz'
    tf.keras.utils.get_file(path, 'https://github.com/neworldemancer/DSF5/raw/master/colab_material.tgz')
    tar = tarfile.open(path, "r:gz")
    tar.extractall()
    tar.close()
# Out:
# Downloading data from https://github.com/neworldemancer/DSF5/raw/master/colab_material.tgz
# 261349/261349 [==============================] - 0s 0us/step

# %%
from utils.routines import *

# %% [markdown]
# # 1. Datasets

# %% [markdown]
# In this course we will use several synthetic and real-world datasets to illustrate the behavior of the models and exercise our skills.

# %% [markdown]
# ## 1. Synthetic linear

# %%
def get_linear(n_d=1, n_points=10, w=None, b=None, sigma=5):
  x = np.random.uniform(0, 10, size=(n_points, n_d))

  w = w or np.random.uniform(0.1, 10, n_d)
  b = b or np.random.uniform(-10, 10)
  y = np.dot(x, w) + b + np.random.normal(0, sigma, size=n_points)

  print('true slopes: w =', w, ';  b =', b)

  return x, y

# %%
x, y = get_linear(n_d=1, sigma=1)
plt.plot(x[:, 0], y, '*')
plt.show()

# %%
n_d = 2
x, y = get_linear(n_d=n_d, n_points=100)

fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x[:,0], x[:,1], y, marker='x', color='b',s=10)
plt.show()

# %% [markdown]
# ## 2. House prices

# %% [markdown]
# Subset of the Ames Houses dataset: http://jse.amstat.org/v19n3/decock.pdf

# %%
def house_prices_dataset(return_df=False, return_df_xy=False, price_max=400000, area_max=40000):
  path = 'data/AmesHousing.csv'

  df = pd.read_csv(path, na_values=('NaN', ''), keep_default_na=False,  )

  rename_dict = {k:k.replace(' ', '').replace('/', '') for k in df.keys()}
  df.rename(columns=rename_dict, inplace=True)

  useful_fields = ['LotArea',
                  'Utilities', 'OverallQual', 'OverallCond',
                  'YearBuilt', 'YearRemodAdd', 'ExterQual', 'ExterCond',
                  'HeatingQC', 'CentralAir', 'Electrical',
                  '1stFlrSF', '2ndFlrSF','GrLivArea',
                  'FullBath', 'HalfBath',
                  'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
                  'Functional','PoolArea',
                  'YrSold', 'MoSold'
                  ]
  target_field = 'SalePrice'

  df.dropna(axis=0, subset=useful_fields+[target_field], inplace=True)

  cleanup_nums = {'Street':      {'Grvl': 0, 'Pave': 1},
                  'LotFrontage': {'NA':0},
                  'Alley':       {'NA':0, 'Grvl': 1, 'Pave': 2},
                  'LotShape':    {'IR3':0, 'IR2': 1, 'IR1': 2, 'Reg':3},
                  'Utilities':   {'ELO':0, 'NoSeWa': 1, 'NoSewr': 2, 'AllPub': 3},
                  'LandSlope':   {'Sev':0, 'Mod': 1, 'Gtl': 3},
                  'ExterQual':   {'Po':0, 'Fa': 1, 'TA': 2, 'Gd': 3, 'Ex':4},
                  'ExterCond':   {'Po':0, 'Fa': 1, 'TA': 2, 'Gd': 3, 'Ex':4},
                  'BsmtQual':    {'NA':0, 'Po':1, 'Fa': 2, 'TA': 3, 'Gd': 4, 'Ex':5},
                  'BsmtCond':    {'NA':0, 'Po':1, 'Fa': 2, 'TA': 3, 'Gd': 4, 'Ex':5},
                  'BsmtExposure':{'NA':0, 'No':1, 'Mn': 2, 'Av': 3, 'Gd': 4},
                  'BsmtFinType1':{'NA':0, 'Unf':1, 'LwQ': 2, 'Rec': 3, 'BLQ': 4, 'ALQ':5, 'GLQ':6},
                  'BsmtFinType2':{'NA':0, 'Unf':1, 'LwQ': 2, 'Rec': 3, 'BLQ': 4, 'ALQ':5, 'GLQ':6},
                  'HeatingQC':   {'Po':0, 'Fa': 1, 'TA': 2, 'Gd': 3, 'Ex':4},
                  'CentralAir':  {'N':0, 'Y': 1},
                  'Electrical':  {'':0, 'NA':0, 'Mix':1, 'FuseP':2, 'FuseF': 3, 'FuseA': 4, 'SBrkr': 5},
                  'KitchenQual': {'Po':0, 'Fa': 1, 'TA': 2, 'Gd': 3, 'Ex':4},
                  'Functional':  {'Sal':0, 'Sev':1, 'Maj2': 2, 'Maj1': 3, 'Mod': 4, 'Min2':5, 'Min1':6, 'Typ':7},
                  'FireplaceQu': {'NA':0, 'Po':1, 'Fa': 2, 'TA': 3, 'Gd': 4, 'Ex':5},
                  'PoolQC':      {'NA':0, 'Fa': 1, 'TA': 2, 'Gd': 3, 'Ex':4},
                  'Fence':       {'NA':0, 'MnWw': 1, 'GdWo': 2, 'MnPrv': 3, 'GdPrv':4},
                  }

  df_X = df[useful_fields].copy()
  df_X.replace(cleanup_nums, inplace=True)  # convert continous categorial variables to numerical
  df_Y = df[target_field].copy()

  x = df_X.to_numpy().astype(np.float32)
  y = df_Y.to_numpy().astype(np.float32)

  if price_max>0:
    idxs = y<price_max
    x = x[idxs]
    y = y[idxs]

  if area_max>0:
    idxs = x[:,0]<area_max
    x = x[idxs]
    y = y[idxs]

  return (x, y, df) if return_df else ((x, y, (df_X, df_Y)) if return_df_xy else (x,y))

# %%
x, y, df = house_prices_dataset(return_df=True)
print(x.shape, y.shape)
df.head()

# %%
df.describe()

# %%
plt.plot(x[:, 0], y, '.')
plt.xlabel('area, sq.ft')
plt.ylabel('price, $');
plt.show()

# %% [markdown]
# ## 3. Blobs

# %%
x, y = make_blobs(n_samples=1000, centers=[[0,0], [5,5], [10, 0]])
colors = "ygr"
for i, color in enumerate(colors):
    idx = y == i
    plt.scatter(x[idx, 0], x[idx, 1], c=color, edgecolor='gray', s=25)
plt.show()

# %%
x, y = make_blobs(n_samples=1000, centers=[[0,0], [5,5], [10, 0]])

transformation = [[0.4, 0.2], [-0.4, 1.2]]  # affine transformation matrix
x = np.dot(x, transformation)               # applied to point coordinated to make blobs less separable

colors = "ygr"
for i, color in enumerate(colors):
    idx = y == i
    plt.scatter(x[idx, 0], x[idx, 1], c=color, edgecolor='gray', s=25)
plt.show()

# %% [markdown]
# ## 4. MNIST

# %% [markdown]
# The MNIST database of handwritten digits has a training set of 60,000 examples, and a test set of 10,000 examples. The digits have been size-normalized and centered in a fixed-size image.
# It is a good database for people who want to try learning techniques and pattern recognition methods on real-world data while spending minimal efforts on preprocessing and formatting (taken from http://yann.lecun.com/exdb/mnist/). Each example is a 28x28 grayscale image and the dataset can be readily downloaded from Tensorflow.

# %%
mnist = tf.keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %% [markdown]
# Let's check few samples:

# %%
n = 3
fig, ax = plt.subplots(n, n, figsize=(2*n, 2*n))
ax = [ax_xy for ax_y in ax for ax_xy in ax_y]
for axi, im_idx in zip(ax, np.random.choice(len(train_images), n**2)):
  im = train_images[im_idx]
  im_class = train_labels[im_idx]
  axi.imshow(im, cmap='gray')
  axi.text(1, 4, f'{im_class}', color='r', size=16)
  axi.grid(False)
plt.tight_layout(pad=0, h_pad=0, w_pad=0)
plt.show()

# %% [markdown]
# ## 5. Fashion MNIST

# %% [markdown]
# `Fashion-MNIST` is a dataset of Zalando's article images—consisting of a training set of 60,000 examples and a test set of 10,000 examples. Each example is a 28x28 grayscale image, associated with a label from 10 classes. (from https://github.com/zalandoresearch/fashion-mnist)

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %% [markdown]
# Let's check few samples:

# %%
n = 3
fig, ax = plt.subplots(n, n, figsize=(2*n, 2*n))
ax = [ax_xy for ax_y in ax for ax_xy in ax_y]
for axi, im_idx in zip(ax, np.random.choice(len(train_images), n**2)):
  im = train_images[im_idx]
  im_class = train_labels[im_idx]
  axi.imshow(im, cmap='gray')
  axi.text(1, 4, f'{im_class}', color='r', size=16)
  axi.grid(False)
plt.tight_layout(0,0,0)
plt.show()

# %%
fmnist_class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# Each of the training and test examples is assigned to one of the following labels:
#
# | Label | Description |
# | --- | --- |
# | 0 | T-shirt/top |
# | 1 | Trouser |
# | 2 | Pullover |
# | 3 | Dress |
# | 4 | Coat |
# | 5 | Sandal |
# | 6 | Shirt |
# | 7 | Sneaker |
# | 8 | Bag |
# | 9 | Ankle boot |

# %% [markdown]
# ## 6. Weather dataset

# %% [markdown]
# This is a weather time series [dataset](https://www.bgc-jena.mpg.de/wetter/) recorded by the Max Planck Institute for Biogeochemistry
# It contains weather reacord for 8 years of observation.

# %%
def get_weather_df():
  # inspired by https://www.tensorflow.org/tutorials/structured_data/time_series

  # download and extract dataset
  zip_path = tf.keras.utils.get_file(
    origin='https://storage.googleapis.com/tensorflow/tf-keras-datasets/jena_climate_2009_2016.csv.zip',
    fname='jena_climate_2009_2016.csv.zip',
    extract=True)
  csv_path, _ = os.path.splitext(zip_path)

  # load into pandas df
  df = pd.read_csv(csv_path)

  # dataset contains records every 10 min, we use hourly records only, thus
  # slice [start:stop:step], starting from index 5 take every 6th record
  df = df[5::6]

  # replace errors in wind velocity to 0
  wv = df['wv (m/s)']
  bad_wv = wv == -9999.0
  wv[bad_wv] = 0.0

  max_wv = df['max. wv (m/s)']
  bad_max_wv = max_wv == -9999.0
  max_wv[bad_max_wv] = 0.0

  # obtain timestamps from text time format
  date_time = pd.to_datetime(df.pop('Date Time'), format='%d.%m.%Y %H:%M:%S')
  timestamp_s = date_time.map(pd.Timestamp.timestamp)
  # genarate cyclic features for year and day
  day = 24*60*60
  year = (365.2425) * day

  df['Day sin'] = np.sin(timestamp_s * (2 * np.pi / day))
  df['Day cos'] = np.cos(timestamp_s * (2 * np.pi / day))
  df['Year sin'] = np.sin(timestamp_s * (2 * np.pi / year))
  df['Year cos'] = np.cos(timestamp_s * (2 * np.pi / year))

  return df

# %%
weather_df = get_weather_df()

# %%
weather_df.head()

# %%
weather_df.describe().T

# %%
plt.plot(weather_df['Year cos'])
plt.plot(weather_df['Year sin'])

# %%
plt.plot(weather_df['Day cos'][:7*24])
plt.plot(weather_df['Day sin'][:7*24])

# %%
def gen_future_T_dataset(X_len=24, Y_offset=48,
                         X_features=['p (mbar)', 'T (degC)', 'rh (%)', 'wv (m/s)', 'wd (deg)', 'Day sin', 'Day cos', 'Year sin', 'Year cos'],
                         Y_features='T (degC)',
                         standardize=True,
                         oversample=10
                         ):
  """
  Generates pairs of input-label, using sequence of `X_len` samples as input
  and value at offset `Y_offset` from start of this sequence as label.
  Sample sequnces arte taken at random positions throughout the dataset.
  Number of samples is obtained assuming non-overlaping wondows.
  Oversampling factor allows to increase this value.

  Args:
    X_len (int): length of sample sequence
    Y_offset (int): offset to the target value from the sequence start
    X_features (list or str): features to be used as input
    Y_features (list or str): features to be used as labels
    standardize (Bool): flag whether to standardize the columns
    oversample (int): increases number of samples by this factor wrt baseline
                      n = len(df) // (Y_offset+1)
  """
  weather_df = get_weather_df()

  if standardize:
    mean = weather_df.mean()
    std = weather_df.std()
    weather_df = (weather_df - mean) / std

  df_X = weather_df[X_features]
  df_Y = weather_df[Y_features]

  n_records = len(df_X)
  sample_len = Y_offset+1
  n_samples = int((n_records-sample_len)//sample_len*oversample)
  offsets = np.random.randint(0, n_records-sample_len, size=n_samples)
  offsets.sort()

  X = []
  Y = []
  for o in offsets:
    X.append(np.array(df_X[o:o+X_len]))
    Y.append(np.array(df_Y[o+Y_offset:o+Y_offset+1]))

  X = np.stack(X)
  Y = np.concatenate(Y)

  return X, Y

# %%
x, y = gen_future_T_dataset()

# %%
x.shape, y.shape

# %%
for f,fn in enumerate(['p (mbar)', 'T (degC)', 'rh (%)', 'wv (m/s)', 'wd (deg)', 'Day sin', 'Day cos', 'Year sin', 'Year cos']):
  plt.figure(figsize=(5*(1+(f==1)), 4))
  for s in range(10):
    plt.plot(x[s, :, f])
    if f==1:
      plt.scatter(48, y[s], color=plt.gca().lines[-1].get_color())
  plt.title(fn)
  plt.show()

# %% [markdown]
# # 2. Neural Networks Introduction

# %% [markdown]
# Train set --> used for training;
# Validation set --> used to evaluate model and optimize;
# Test set --> you put it in a safebox and do not touch it. This is used in the end to check whether we overfitted to the validation set. The Test set is used ONCE only!

# %% [markdown]
# ## 1. Perceptron

# %% [markdown]
# (Artificial) Neural network consists of layers of neurons. Artificial neuron, or perceptron, is in fact inspired by a biological neuron.
#
# <img src="https://github.com/neworldemancer/DSF5/raw/master/figures/Perceptron.png" alt="drawing" width="30%"/>
#
# Such neuron first calculates the linear transformation of the input vector $\bar x$:
# $$z = \bar W \cdot \bar x + b = \sum {W_i x_i} + b$$ where $\bar W$ is vector of weights and $b$ - bias.

# %% [markdown]
# This is effectively linear regression. You can combine those parallely to make a multidimensional prediction, e.g.:
#
# <img src="https://github.com/neworldemancer/DSF5/raw/master/figures/2Perceptrons.png" alt="drawing" width="30%"/>

# %% [markdown]
# It is strongly recommended that you input standardized values into the neural network.

# %% [markdown]
# ## 2. Nonlinearity

# %% [markdown]
# Combining multiple such objects performing linear transformation sequentially would not bring any additional benefit, as the combined output would still be a linear combination of the inputs.
#
# What gives actual power to neurons, is that they additionally perform the nonlinear transformation of the result using activation function $f$ $$y = f(z)$$
#
# The most commonly used non-linear transformations are:

# %%
def ReLU(z):
  return np.clip(z, a_min=0, a_max=np.max(z))
def SELU(z, a=1):
  p = np.clip(z, a_min=0, a_max=np.max(z))
  n = np.clip(z, a_min=np.min(z), a_max=0)
  return p + (np.exp(n)-1) * a
def LReLU(z, a=0.1):
  return np.clip(z, a_min=0, a_max=np.max(z)) + np.clip(z, a_min=np.min(z), a_max=0) * a
def sigmoid(z):
  return 1/(1 + np.exp(-z))
def step(z):
  return np.heaviside(z, 0)
fig, ax = plt.subplots(1, 6, figsize=(18, 3))
z = np.linspace(-10, 10, 100)
ax[0].plot(z, ReLU(z))
ax[0].set_title('Rectified Linear Unit (LU)')
ax[1].plot(z, LReLU(z))
ax[1].set_title('Leaky Rectified LU')
ax[2].plot(z, SELU(z))
ax[2].set_title('Scaled Exponential LU')
ax[3].plot(z, sigmoid(z))
ax[3].set_title(r'$\sigma$(z)=$\frac{1}{1+e^z}$')
ax[4].plot(z, np.tanh(z))
ax[4].set_title('Hyperbolic tangent');
ax[5].plot(z, step(z))
ax[5].text(-6, 0.5, 'NOT USED', size=19, c='r')
ax[5].set_title('Step function');
for axi in ax:
  axi.set_xlabel('z')
plt.show()

# %% [markdown]
# And the reason we don't use a simple step function, is that it's everywhere either not differentiable or its derivative is zero. --> we cannot determin the gradient
#
# ReLU --> for inputs less than 0 it is 0, for inputs more than zero it takes the value of the input
#
# The last nonlinearity to mention here is *softmax*:
# $$y_i = SoftMax(\bar z)_i = \frac{ e^{z_i}}{\sum_j e^{z_j}}$$
#
# While each $z_i$ can have any value, the corresponding $y_i\in[0,1]$, and $\sum_i y_i=1$, just like probabilities!
#
# While these $y_i$ are only pseudo-probabilities, this nonlinearity allows one to model probabilities, e.g. of a data-point belonging to a certain class.

# %% [markdown]
# ## 3. Fully connected net

# %% [markdown]
# In a fully connected neural network each layer is a set of N neurons, performing different transformations of all the same layer's inputs $\bar x = [x_i]$ producing output vector $\bar y = [y_j]_{i=1..N}$: $$y_j = f(\bar W_j \cdot \bar x + b_j)$$
#
# Since output of each layer forms input of next layer, one can write for layer $l$ (upper index denotes layer): $$x^l_j = f(\bar W^l_j \cdot \bar x^{l-1} + b^l_j)$$ where $\bar x^0$ is network's input vector.
#
# <img src="https://github.com/neworldemancer/DSF5/raw/master/figures/MLP.png" alt="drawing" width="50%"/>

# %% [markdown]
# The first layer does some strange nonlinear transformation, same for the second etc. The last transformation will be softmax.
#
# Using the intermediate layers you build some new intermediate features from which it is easier to extract information compared to the input data. So the task/benefit of the NN-Layers is that they create 'clearer' intermediate features.

# %% [markdown]
# ## 4. Loss function

# %% [markdown]
# The last part of the puzzle is the measure of network performance, which is used to optimize the network's parameters $W^l_j$ and $b^l_j$.
# Denoting the network's output for an input $x_i$ as $\hat y_i=\hat y_i(x_i)$ and given the label $y_i$:
#
# 1. In case of regression loss shows "distance" from target values:
# * L2 (MSE): $L = \sum_i (y_i-\hat y_i)^2$
# * L1 (MAE): $L = \sum_i |y_i-\hat y_i|$
#
# 1. In case of classification we can use cross-entropy, which shows "distance" from target distribution:
# $$L = - \sum_i \sum_c y_{i,c} \log(\hat y_{i,c})$$
# Here $\hat y_{i,c}$ - pseudo-probability of $x_i$ belonging to class $c$ and $y_{i,c}$ uses 1-hot encoding:
#
# $$y_{i,c}=
# \begin{cases}
#     1,& \text{if } x_i \text{ belongs to class } c\\
#     0,              & \text{otherwise}
# \end{cases}$$

# %% [markdown]
# ## 5. Training

# %% [markdown]
# Training of neural networks is performed iteratively. The weights  $W^l_j$ and $b^l_j$ are updated on each iteration of training according to the value of the derivative of the loss function with respect to corresponding parameter:
# $$W^l_j \rightarrow W^l_j - \lambda \frac{\partial L}{\partial W^l_j }$$
# $$b^l_j \rightarrow b^l_j - \lambda \frac{\partial L}{\partial b^l_j },$$
#
# This is Gradient Descent optimization with learning rate $\lambda$. The partial derivatives are calculated by the chain law, and this approach is known as [backpropagation](https://en.wikipedia.org/wiki/Backpropagation).
#
# In practice often for each iteration the loss $L$ is evaluated not on all samples, but on a sub-sample, so-called *minibatch* (sometimes - just batch). In most cases the sample order and selection for each minibatch is performed at random rendering this approach to be stochastic (thus it's called [Stochastic Gradient Descent](https://en.wikipedia.org/wiki/Stochastic_gradient_descent)). One iteration through all training data in minibatches is called *epoch*.

# %% [markdown]
# # 3. Regression with neural network

# %% [markdown]
# ## 2. 1D input

# %%
x = np.linspace(0, 10, num=1000)
y = ((x>3)*(x<5)).astype(np.float32)

#y = x**3/500 + np.sin(x) #+ np.sin((10-x)**2)

x /= 10
x -= 0.5
plt.plot(x, y);

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(1,)),
  tf.keras.layers.Dense(100, activation='relu'), #first layer has 100 neurons --> takes 1 input and creates 100 neurons
  tf.keras.layers.Dense(1, activation=None), #this is the output layer, 1 output and no activation function
])
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
              loss='mae',
              metrics=['mse'])
model.summary()

#trainable parameters are weights and bias
#100 neurons, each has 1 bias and 1 weight hence 200 params
#last layer: 100 weights and 1 bias
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 1)                 0
#
#  dense_2 (Dense)             (None, 100)               200
#
#  dense_3 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 301 (1.18 KB)
# Trainable params: 301 (1.18 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
class saving_pred(tf.keras.callbacks.Callback):
  def __init__(self):
    self.y_preds = []

  def on_epoch_end(self, epoch, logs=None):
    if epoch % 10 == 0:
        y_p = model.predict(x).flatten()
        #print('\n', epoch, y_p.shape, '\n\n')
        self.y_preds.append(y_p)

# %%
saving_callback = saving_pred()
hist = model.fit(x, y,
                 epochs=300, batch_size=100, callbacks=[saving_callback])
# Out:
# Epoch 1/300
# 32/32 [==============================] - 0s 984us/steps: 0.2192 - mse: 0.18
# 10/10 [==============================] - 1s 23ms/step - loss: 0.2248 - mse: 0.1848
# Epoch 2/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2060 - mse: 0.1768
# Epoch 3/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1991 - mse: 0.1711
# Epoch 4/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1970 - mse: 0.1692
# Epoch 5/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1987 - mse: 0.1714
# Epoch 6/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1983 - mse: 0.1689
# Epoch 7/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1993 - mse: 0.1675
# Epoch 8/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2007 - mse: 0.1652
# Epoch 9/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1998 - mse: 0.1626
# Epoch 10/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1950 - mse: 0.1591
# Epoch 11/300
# 32/32 [==============================] - 0s 1ms/steposs: 0.2110 - mse: 0.17
# 10/10 [==============================] - 0s 13ms/step - loss: 0.1953 - mse: 0.1594
# Epoch 12/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1964 - mse: 0.1571
# Epoch 13/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1947 - mse: 0.1532
# Epoch 14/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1938 - mse: 0.1511
# Epoch 15/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1926 - mse: 0.1488
# Epoch 16/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1924 - mse: 0.1440
# Epoch 17/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1920 - mse: 0.1407
# Epoch 18/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1927 - mse: 0.1367
# Epoch 19/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1886 - mse: 0.1311
# Epoch 20/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1902 - mse: 0.1276
# Epoch 21/300
# 32/32 [==============================] - 0s 2ms/steposs: 0.2157 - mse: 0.
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1881 - mse: 0.1206
# Epoch 22/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1854 - mse: 0.1166
# Epoch 23/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1875 - mse: 0.1096
# Epoch 24/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1881 - mse: 0.1036
# Epoch 25/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1846 - mse: 0.0983
# Epoch 26/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1823 - mse: 0.0954
# Epoch 27/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1782 - mse: 0.0891
# Epoch 28/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1790 - mse: 0.0861
# Epoch 29/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1767 - mse: 0.0777
# Epoch 30/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1746 - mse: 0.0732
# Epoch 31/300
# 32/32 [==============================] - 0s 993us/steps: 0.1787 - mse: 0.07
# 10/10 [==============================] - 0s 12ms/step - loss: 0.1741 - mse: 0.0718
# Epoch 32/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1739 - mse: 0.0678
# Epoch 33/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1660 - mse: 0.0619
# Epoch 34/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1612 - mse: 0.0574
# Epoch 35/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1672 - mse: 0.0626
# Epoch 36/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1645 - mse: 0.0599
# Epoch 37/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1663 - mse: 0.0634
# Epoch 38/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1658 - mse: 0.0605
# Epoch 39/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1591 - mse: 0.0581
# Epoch 40/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1610 - mse: 0.0624
# Epoch 41/300
# 32/32 [==============================] - 0s 1ms/steposs: 0.1593 - mse: 0.05
# 10/10 [==============================] - 0s 16ms/step - loss: 0.1493 - mse: 0.0524
# Epoch 42/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1504 - mse: 0.0545
# Epoch 43/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1459 - mse: 0.0498
# Epoch 44/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1458 - mse: 0.0519
# Epoch 45/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1484 - mse: 0.0547
# Epoch 46/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1502 - mse: 0.0553
# Epoch 47/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1514 - mse: 0.0525
# Epoch 48/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1431 - mse: 0.0508
# Epoch 49/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1472 - mse: 0.0527
# Epoch 50/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1375 - mse: 0.0498
# Epoch 51/300
# 32/32 [==============================] - 0s 1ms/steposs: 0.1659 - mse: 0.05
# 10/10 [==============================] - 0s 13ms/step - loss: 0.1366 - mse: 0.0467
# Epoch 52/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1384 - mse: 0.0482
# Epoch 53/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1421 - mse: 0.0522
# Epoch 54/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1399 - mse: 0.0497
# Epoch 55/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1381 - mse: 0.0487
# Epoch 56/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1521 - mse: 0.0559
# Epoch 57/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1457 - mse: 0.0552
# Epoch 58/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1449 - mse: 0.0537
# Epoch 59/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1439 - mse: 0.0495
# Epoch 60/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1370 - mse: 0.0492
# Epoch 61/300
# 32/32 [==============================] - 0s 1ms/steposs: 0.1141 - mse: 0.03
# 10/10 [==============================] - 0s 12ms/step - loss: 0.1405 - mse: 0.0503
# Epoch 62/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1333 - mse: 0.0469
# Epoch 63/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1324 - mse: 0.0473
# Epoch 64/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1345 - mse: 0.0453
# Epoch 65/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1349 - mse: 0.0458
# Epoch 66/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1340 - mse: 0.0464
# Epoch 67/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1329 - mse: 0.0464
# Epoch 68/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1288 - mse: 0.0457
# Epoch 69/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1312 - mse: 0.0455
# Epoch 70/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1345 - mse: 0.0466
# Epoch 71/300
# 32/32 [==============================] - 0s 907us/steps: 0.1421 - mse: 0.04
# 10/10 [==============================] - 0s 12ms/step - loss: 0.1312 - mse: 0.0447
# Epoch 72/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1379 - mse: 0.0506
# Epoch 73/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1550 - mse: 0.0647
# Epoch 74/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1500 - mse: 0.0583
# Epoch 75/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1368 - mse: 0.0484
# Epoch 76/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1324 - mse: 0.0466
# Epoch 77/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1345 - mse: 0.0467
# Epoch 78/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1300 - mse: 0.0454
# Epoch 79/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1321 - mse: 0.0450
# Epoch 80/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1261 - mse: 0.0433
# Epoch 81/300
# 32/32 [==============================] - 0s 1ms/steposs: 0.1254 - mse: 0.04
# 10/10 [==============================] - 0s 12ms/step - loss: 0.1307 - mse: 0.0463
# Epoch 82/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1389 - mse: 0.0529
# Epoch 83/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1319 - mse: 0.0456
# Epoch 84/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1287 - mse: 0.0440
# Epoch 85/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1323 - mse: 0.0453
# Epoch 86/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1295 - mse: 0.0441
# Epoch 87/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1257 - mse: 0.0438
# Epoch 88/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1292 - mse: 0.0456
# Epoch 89/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1306 - mse: 0.0459
# Epoch 90/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1294 - mse: 0.0458
# Epoch 91/300
# 32/32 [==============================] - 0s 1ms/steposs: 0.1302 - mse: 0.04
# 10/10 [==============================] - 0s 12ms/step - loss: 0.1257 - mse: 0.0435
# Epoch 92/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1247 - mse: 0.0413
# Epoch 93/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1249 - mse: 0.0430
# Epoch 94/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1193 - mse: 0.0411
# Epoch 95/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1195 - mse: 0.0388
# Epoch 96/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1140 - mse: 0.0376
# Epoch 97/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1135 - mse: 0.0369
# Epoch 98/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1249 - mse: 0.0420
# Epoch 99/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1209 - mse: 0.0414
# Epoch 100/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1124 - mse: 0.0356
# Epoch 101/300
# 32/32 [==============================] - 0s 1ms/steposs: 0.1077 - mse: 0.03
# 10/10 [==============================] - 0s 12ms/step - loss: 0.1055 - mse: 0.0324
# Epoch 102/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1014 - mse: 0.0308
# Epoch 103/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0977 - mse: 0.0289
# Epoch 104/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0963 - mse: 0.0286
# Epoch 105/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1061 - mse: 0.0331
# Epoch 106/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1002 - mse: 0.0283
# Epoch 107/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0963 - mse: 0.0275
# Epoch 108/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1176 - mse: 0.0371
# Epoch 109/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1354 - mse: 0.0481
# Epoch 110/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1085 - mse: 0.0316
# Epoch 111/300
# 32/32 [==============================] - 0s 978us/steps: 0.1401 - mse: 0.04
# 10/10 [==============================] - 0s 12ms/step - loss: 0.1030 - mse: 0.0302
# Epoch 112/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0939 - mse: 0.0263
# Epoch 113/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0902 - mse: 0.0258
# Epoch 114/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0825 - mse: 0.0243
# Epoch 115/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0784 - mse: 0.0232
# Epoch 116/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0921 - mse: 0.0265
# Epoch 117/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0918 - mse: 0.0253
# Epoch 118/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0798 - mse: 0.0229
# Epoch 119/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0824 - mse: 0.0229
# Epoch 120/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0764 - mse: 0.0219
# Epoch 121/300
# 32/32 [==============================] - 0s 963us/steps: 0.0710 - mse: 0.01
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0731 - mse: 0.0213
# Epoch 122/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0819 - mse: 0.0237
# Epoch 123/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0800 - mse: 0.0226
# Epoch 124/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0923 - mse: 0.0258
# Epoch 125/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0836 - mse: 0.0233
# Epoch 126/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0843 - mse: 0.0231
# Epoch 127/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0737 - mse: 0.0212
# Epoch 128/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0789 - mse: 0.0221
# Epoch 129/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0854 - mse: 0.0229
# Epoch 130/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0702 - mse: 0.0199
# Epoch 131/300
# 32/32 [==============================] - 0s 963us/steps: 0.0684 - mse: 0.01
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0924 - mse: 0.0251
# Epoch 132/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0882 - mse: 0.0241
# Epoch 133/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0952 - mse: 0.0264
# Epoch 134/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1026 - mse: 0.0290
# Epoch 135/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1249 - mse: 0.0378
# Epoch 136/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0906 - mse: 0.0233
# Epoch 137/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0860 - mse: 0.0230
# Epoch 138/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1011 - mse: 0.0278
# Epoch 139/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1092 - mse: 0.0322
# Epoch 140/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1476 - mse: 0.0536
# Epoch 141/300
# 32/32 [==============================] - 0s 1ms/steposs: 0.1648 - mse: 0.06
# 10/10 [==============================] - 0s 13ms/step - loss: 0.1403 - mse: 0.0467
# Epoch 142/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1087 - mse: 0.0308
# Epoch 143/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0869 - mse: 0.0229
# Epoch 144/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0794 - mse: 0.0211
# Epoch 145/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0724 - mse: 0.0199
# Epoch 146/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0834 - mse: 0.0223
# Epoch 147/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1066 - mse: 0.0303
# Epoch 148/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1025 - mse: 0.0280
# Epoch 149/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1012 - mse: 0.0283
# Epoch 150/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0731 - mse: 0.0207
# Epoch 151/300
# 32/32 [==============================] - 0s 981us/steps: 0.0995 - mse: 0.03
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0633 - mse: 0.0187
# Epoch 152/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0714 - mse: 0.0196
# Epoch 153/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1010 - mse: 0.0277
# Epoch 154/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0827 - mse: 0.0214
# Epoch 155/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0689 - mse: 0.0193
# Epoch 156/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0674 - mse: 0.0187
# Epoch 157/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0631 - mse: 0.0181
# Epoch 158/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0736 - mse: 0.0191
# Epoch 159/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0657 - mse: 0.0187
# Epoch 160/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0649 - mse: 0.0181
# Epoch 161/300
# 32/32 [==============================] - 0s 963us/steps: 0.0531 - mse: 0.01
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0640 - mse: 0.0184
# Epoch 162/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0732 - mse: 0.0201
# Epoch 163/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0904 - mse: 0.0235
# Epoch 164/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0860 - mse: 0.0229
# Epoch 165/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0866 - mse: 0.0235
# Epoch 166/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0989 - mse: 0.0270
# Epoch 167/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0841 - mse: 0.0211
# Epoch 168/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0709 - mse: 0.0183
# Epoch 169/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0623 - mse: 0.0178
# Epoch 170/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0675 - mse: 0.0186
# Epoch 171/300
# 32/32 [==============================] - 0s 963us/steps: 0.0977 - mse: 0.02
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0798 - mse: 0.0200
# Epoch 172/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0669 - mse: 0.0176
# Epoch 173/300
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0597 - mse: 0.0171
# Epoch 174/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0728 - mse: 0.0192
# Epoch 175/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0774 - mse: 0.0205
# Epoch 176/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0704 - mse: 0.0185
# Epoch 177/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0736 - mse: 0.0195
# Epoch 178/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0807 - mse: 0.0217
# Epoch 179/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0630 - mse: 0.0176
# Epoch 180/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0653 - mse: 0.0183
# Epoch 181/300
# 32/32 [==============================] - 0s 893us/steps: 0.0811 - mse: 0.02
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0759 - mse: 0.0193
# Epoch 182/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0751 - mse: 0.0203
# Epoch 183/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0737 - mse: 0.0201
# Epoch 184/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0632 - mse: 0.0174
# Epoch 185/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0803 - mse: 0.0210
# Epoch 186/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0900 - mse: 0.0238
# Epoch 187/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0621 - mse: 0.0175
# Epoch 188/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0716 - mse: 0.0185
# Epoch 189/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0659 - mse: 0.0173
# Epoch 190/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0644 - mse: 0.0174
# Epoch 191/300
# 32/32 [==============================] - 0s 1ms/steposs: 0.0809 - mse: 0.02
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0620 - mse: 0.0169
# Epoch 192/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0778 - mse: 0.0210
# Epoch 193/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0624 - mse: 0.0169
# Epoch 194/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0617 - mse: 0.0170
# Epoch 195/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0659 - mse: 0.0180
# Epoch 196/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0788 - mse: 0.0196
# Epoch 197/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0733 - mse: 0.0187
# Epoch 198/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0581 - mse: 0.0167
# Epoch 199/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0868 - mse: 0.0228
# Epoch 200/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0863 - mse: 0.0223
# Epoch 201/300
# 32/32 [==============================] - 0s 950us/steps: 0.1031 - mse: 0.02
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0938 - mse: 0.0253
# Epoch 202/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1007 - mse: 0.0267
# Epoch 203/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1177 - mse: 0.0358
# Epoch 204/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0861 - mse: 0.0230
# Epoch 205/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0912 - mse: 0.0239
# Epoch 206/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0899 - mse: 0.0227
# Epoch 207/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0722 - mse: 0.0181
# Epoch 208/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0598 - mse: 0.0165
# Epoch 209/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0589 - mse: 0.0163
# Epoch 210/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0625 - mse: 0.0165
# Epoch 211/300
# 32/32 [==============================] - 0s 946us/steps: 0.0550 - mse: 0.01
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0649 - mse: 0.0169
# Epoch 212/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0623 - mse: 0.0162
# Epoch 213/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0693 - mse: 0.0180
# Epoch 214/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0780 - mse: 0.0199
# Epoch 215/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0703 - mse: 0.0183
# Epoch 216/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0548 - mse: 0.0158
# Epoch 217/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0597 - mse: 0.0164
# Epoch 218/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0567 - mse: 0.0161
# Epoch 219/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0710 - mse: 0.0184
# Epoch 220/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0761 - mse: 0.0194
# Epoch 221/300
# 32/32 [==============================] - 0s 958us/steps: 0.0653 - mse: 0.01
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0723 - mse: 0.0175
# Epoch 222/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0747 - mse: 0.0187
# Epoch 223/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0743 - mse: 0.0193
# Epoch 224/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0715 - mse: 0.0184
# Epoch 225/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0595 - mse: 0.0162
# Epoch 226/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0692 - mse: 0.0184
# Epoch 227/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0639 - mse: 0.0171
# Epoch 228/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0783 - mse: 0.0203
# Epoch 229/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0916 - mse: 0.0244
# Epoch 230/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0933 - mse: 0.0234
# Epoch 231/300
# 32/32 [==============================] - 0s 991us/steps: 0.1272 - mse: 0.03
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1043 - mse: 0.0286
# Epoch 232/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0609 - mse: 0.0163
# Epoch 233/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0569 - mse: 0.0157
# Epoch 234/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0674 - mse: 0.0177
# Epoch 235/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0599 - mse: 0.0161
# Epoch 236/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0696 - mse: 0.0179
# Epoch 237/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0659 - mse: 0.0174
# Epoch 238/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0724 - mse: 0.0190
# Epoch 239/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0695 - mse: 0.0172
# Epoch 240/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0717 - mse: 0.0180
# Epoch 241/300
# 32/32 [==============================] - 0s 1ms/steposs: 0.0898 - mse: 0.02
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0656 - mse: 0.0169
# Epoch 242/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0591 - mse: 0.0158
# Epoch 243/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0566 - mse: 0.0159
# Epoch 244/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0602 - mse: 0.0162
# Epoch 245/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0714 - mse: 0.0179
# Epoch 246/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0712 - mse: 0.0178
# Epoch 247/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0630 - mse: 0.0164
# Epoch 248/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0774 - mse: 0.0191
# Epoch 249/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0912 - mse: 0.0238
# Epoch 250/300
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0713 - mse: 0.0177
# Epoch 251/300
# 32/32 [==============================] - 0s 1ms/steposs: 0.0533 - mse: 0.01
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0744 - mse: 0.0190
# Epoch 252/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0706 - mse: 0.0176
# Epoch 253/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0612 - mse: 0.0158
# Epoch 254/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0557 - mse: 0.0153
# Epoch 255/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0635 - mse: 0.0162
# Epoch 256/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0814 - mse: 0.0206
# Epoch 257/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0697 - mse: 0.0177
# Epoch 258/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0666 - mse: 0.0169
# Epoch 259/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0671 - mse: 0.0174
# Epoch 260/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0562 - mse: 0.0153
# Epoch 261/300
# 32/32 [==============================] - 0s 1ms/steposs: 0.0730 - mse: 0.01
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0722 - mse: 0.0181
# Epoch 262/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0568 - mse: 0.0154
# Epoch 263/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0564 - mse: 0.0152
# Epoch 264/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0671 - mse: 0.0166
# Epoch 265/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0658 - mse: 0.0167
# Epoch 266/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0659 - mse: 0.0169
# Epoch 267/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0728 - mse: 0.0182
# Epoch 268/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0728 - mse: 0.0183
# Epoch 269/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0594 - mse: 0.0157
# Epoch 270/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0590 - mse: 0.0157
# Epoch 271/300
# 32/32 [==============================] - 0s 959us/steps: 0.0645 - mse: 0.01
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0578 - mse: 0.0152
# Epoch 272/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0616 - mse: 0.0162
# Epoch 273/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0617 - mse: 0.0160
# Epoch 274/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0672 - mse: 0.0170
# Epoch 275/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0583 - mse: 0.0151
# Epoch 276/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0648 - mse: 0.0161
# Epoch 277/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0936 - mse: 0.0249
# Epoch 278/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0927 - mse: 0.0241
# Epoch 279/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0714 - mse: 0.0185
# Epoch 280/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0558 - mse: 0.0151
# Epoch 281/300
# 32/32 [==============================] - 0s 2ms/steposs: 0.0491 - mse: 0.
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0597 - mse: 0.0156
# Epoch 282/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0677 - mse: 0.0175
# Epoch 283/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0703 - mse: 0.0171
# Epoch 284/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0642 - mse: 0.0157
# Epoch 285/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0849 - mse: 0.0216
# Epoch 286/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0593 - mse: 0.0155
# Epoch 287/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0512 - mse: 0.0145
# Epoch 288/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0555 - mse: 0.0149
# Epoch 289/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0562 - mse: 0.0150
# Epoch 290/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0569 - mse: 0.0148
# Epoch 291/300
# 32/32 [==============================] - 0s 1ms/steposs: 0.0601 - mse: 0.01
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0511 - mse: 0.0146
# Epoch 292/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0524 - mse: 0.0146
# Epoch 293/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0558 - mse: 0.0149
# Epoch 294/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0640 - mse: 0.0163
# Epoch 295/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0654 - mse: 0.0166
# Epoch 296/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0645 - mse: 0.0163
# Epoch 297/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0693 - mse: 0.0172
# Epoch 298/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0604 - mse: 0.0157
# Epoch 299/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0817 - mse: 0.0204
# Epoch 300/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1045 - mse: 0.0282

# %%
fig, axs = plt.subplots(1, 2, figsize=(10,5))
axs[0].plot(hist.epoch, hist.history['loss'])
axs[0].set_title('loss')
axs[1].plot(hist.epoch, hist.history['mse'])
axs[1].set_title('mse')
plt.show()

# %%
y_p = model.predict(x)
im = plt.plot(x, y_p)
im = plt.plot(x, y, '--')
plt.show()
# Out:
# 32/32 [==============================] - 0s 1ms/step

# %%
# %%capture
y_preds = saving_callback.y_preds

fig = plt.figure()
line = plt.plot(x, y_preds[0])
line2 = plt.plot(x, y)

def animate(i):
    y_p = y_preds[i]
    line[0].set_data((x, y_p))
    return line

ani = animation.FuncAnimation(fig, animate, frames=len(y_preds))

# %%
ani
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img74fe552e451045caadfcc0c557afd24c">
#   <div class="anim-controls">
#     <input id="_anim_slider74fe552e451045caadfcc0c557afd24c" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim74fe552e451045caadfcc0c557afd24c.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim74fe552e451045caadfcc0c557afd24c.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim74fe552e451045caadfcc0c557afd24c.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim74fe552e451045caadfcc0c557afd24c.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim74fe552e451045caadfcc0c557afd24c.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim74fe552e451045caadfcc0c557afd24c.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim74fe552e451045caadfcc0c557afd24c.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim74fe552e451045caadfcc0c557afd24c.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim74fe552e451045caadfcc0c557afd24c.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim74fe552e451045caadfcc0c557afd24c.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select74fe552e451045caadfcc0c557afd24c"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_74fe552e451045caadfcc0c557afd24c"
#              >
#       <label for="_anim_radio1_74fe552e451045caadfcc0c557afd24c">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_74fe552e451045caadfcc0c557afd24c"
#              checked>
#       <label for="_anim_radio2_74fe552e451045caadfcc0c557afd24c">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_74fe552e451045caadfcc0c557afd24c"
#              >
#       <label for="_anim_radio3_74fe552e451045caadfcc0c557afd24c">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img74fe552e451045caadfcc0c557afd24c";
#     var slider_id = "_anim_slider74fe552e451045caadfcc0c557afd24c";
#     var loop_select_id = "_anim_loop_select74fe552e451045caadfcc0c557afd24c";
#     var frames = new Array(30);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjcuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/bCgiHAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAAwg0lEQ

# %% [markdown]
# ## 2. 2D input

# %% [markdown]
# Here we will build a neural network to perform regression in 2D: we will fit $(x,y)$ pixel coordinates of an image to the pixel brightness at that location.

# %%
url = 'https://github.com/neworldemancer/DSF5/raw/master/figures/unibe.jpg'
image_big = imread(url)
image_big = image_big[...,0:3]/255
plt.imshow(image_big)
plt.show()
# Out:
# /var/folders/k1/tlc1r2s97gj6r2x8xm2cchlh0000gn/T/ipykernel_51371/1793758380.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image_big = imread(url)

# %%
def subsample(im, factor):
  h, w = im.shape[:2]
  h = int(h/factor)
  w = int(w/factor)

  img = Image.fromarray((im*255).astype('uint8'))
  newimg = img.resize((w, h), Image.ANTIALIAS)
  return np.asarray(newimg)/255

# %%
image = subsample(image_big, 15)
image = image.mean(axis=2, keepdims=True)
plt.imshow(image[...,0], cmap='gray')
plt.show()
# Out:
# /var/folders/k1/tlc1r2s97gj6r2x8xm2cchlh0000gn/T/ipykernel_51371/2121674518.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   newimg = img.resize((w, h), Image.ANTIALIAS)

# %%
h, w, c = image.shape

# %%
X0 = np.meshgrid(np.linspace(0, 1, w), np.linspace(0, 1, h))
X = np.stack(X0, axis=-1).reshape((-1, 2))

Y = image.reshape((-1, c))
X.shape, Y.shape

#input has 2 columns (x and y coordinate), output has 1 column which is brightness at the location
# Out:
# ((2400, 2), (2400, 1))

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(2,)),
  tf.keras.layers.Dense(c, activation='sigmoid'),
])
model.compile(optimizer='adam',
              loss='mae',
              metrics=['mse'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 2)                 0
#
#  dense_4 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 3 (12.00 Byte)
# Trainable params: 3 (12.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
hist = model.fit(X, Y, epochs=500, batch_size=2048)
# Out:
# Epoch 1/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1612 - mse: 0.0356
# Epoch 2/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1609 - mse: 0.0355
# Epoch 3/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1606 - mse: 0.0353
# Epoch 4/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1602 - mse: 0.0352
# Epoch 5/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1599 - mse: 0.0351
# Epoch 6/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1596 - mse: 0.0350
# Epoch 7/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1594 - mse: 0.0349
# Epoch 8/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1591 - mse: 0.0348
# Epoch 9/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1588 - mse: 0.0346
# Epoch 10/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1585 - mse: 0.0345
# Epoch 11/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1583 - mse: 0.0344
# Epoch 12/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1580 - mse: 0.0343
# Epoch 13/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1577 - mse: 0.0342
# Epoch 14/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1575 - mse: 0.0341
# Epoch 15/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1573 - mse: 0.0340
# Epoch 16/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1570 - mse: 0.0339
# Epoch 17/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1568 - mse: 0.0338
# Epoch 18/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1566 - mse: 0.0338
# Epoch 19/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1564 - mse: 0.0337
# Epoch 20/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1562 - mse: 0.0336
# Epoch 21/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1560 - mse: 0.0335
# Epoch 22/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1558 - mse: 0.0334
# Epoch 23/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1556 - mse: 0.0334
# Epoch 24/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1555 - mse: 0.0333
# Epoch 25/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1553 - mse: 0.0332
# Epoch 26/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1551 - mse: 0.0332
# Epoch 27/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1550 - mse: 0.0331
# Epoch 28/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1548 - mse: 0.0330
# Epoch 29/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1547 - mse: 0.0330
# Epoch 30/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1545 - mse: 0.0329
# Epoch 31/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1544 - mse: 0.0329
# Epoch 32/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1543 - mse: 0.0328
# Epoch 33/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1541 - mse: 0.0328
# Epoch 34/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1540 - mse: 0.0327
# Epoch 35/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1539 - mse: 0.0327
# Epoch 36/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1538 - mse: 0.0326
# Epoch 37/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1536 - mse: 0.0326
# Epoch 38/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1535 - mse: 0.0325
# Epoch 39/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1534 - mse: 0.0325
# Epoch 40/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1533 - mse: 0.0324
# Epoch 41/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1532 - mse: 0.0324
# Epoch 42/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1531 - mse: 0.0323
# Epoch 43/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1530 - mse: 0.0323
# Epoch 44/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1529 - mse: 0.0323
# Epoch 45/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1528 - mse: 0.0322
# Epoch 46/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1528 - mse: 0.0322
# Epoch 47/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1527 - mse: 0.0322
# Epoch 48/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1526 - mse: 0.0321
# Epoch 49/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1525 - mse: 0.0321
# Epoch 50/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1524 - mse: 0.0321
# Epoch 51/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1523 - mse: 0.0320
# Epoch 52/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1522 - mse: 0.0320
# Epoch 53/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1521 - mse: 0.0320
# Epoch 54/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1521 - mse: 0.0319
# Epoch 55/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1520 - mse: 0.0319
# Epoch 56/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1519 - mse: 0.0319
# Epoch 57/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1518 - mse: 0.0318
# Epoch 58/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1518 - mse: 0.0318
# Epoch 59/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1517 - mse: 0.0318
# Epoch 60/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1516 - mse: 0.0318
# Epoch 61/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1516 - mse: 0.0317
# Epoch 62/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1515 - mse: 0.0317
# Epoch 63/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1514 - mse: 0.0317
# Epoch 64/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1514 - mse: 0.0317
# Epoch 65/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1513 - mse: 0.0316
# Epoch 66/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1512 - mse: 0.0316
# Epoch 67/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1512 - mse: 0.0316
# Epoch 68/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1511 - mse: 0.0316
# Epoch 69/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1510 - mse: 0.0315
# Epoch 70/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1510 - mse: 0.0315
# Epoch 71/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1509 - mse: 0.0315
# Epoch 72/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1509 - mse: 0.0315
# Epoch 73/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1508 - mse: 0.0315
# Epoch 74/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1507 - mse: 0.0314
# Epoch 75/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1507 - mse: 0.0314
# Epoch 76/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1506 - mse: 0.0314
# Epoch 77/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1506 - mse: 0.0314
# Epoch 78/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1505 - mse: 0.0314
# Epoch 79/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1505 - mse: 0.0313
# Epoch 80/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1504 - mse: 0.0313
# Epoch 81/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1503 - mse: 0.0313
# Epoch 82/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1503 - mse: 0.0313
# Epoch 83/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1502 - mse: 0.0312
# Epoch 84/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1502 - mse: 0.0312
# Epoch 85/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1501 - mse: 0.0312
# Epoch 86/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1501 - mse: 0.0312
# Epoch 87/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1500 - mse: 0.0312
# Epoch 88/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1500 - mse: 0.0312
# Epoch 89/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1499 - mse: 0.0311
# Epoch 90/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1498 - mse: 0.0311
# Epoch 91/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1498 - mse: 0.0311
# Epoch 92/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1497 - mse: 0.0311
# Epoch 93/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1497 - mse: 0.0311
# Epoch 94/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1496 - mse: 0.0310
# Epoch 95/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1496 - mse: 0.0310
# Epoch 96/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1495 - mse: 0.0310
# Epoch 97/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1495 - mse: 0.0310
# Epoch 98/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1494 - mse: 0.0310
# Epoch 99/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1494 - mse: 0.0309
# Epoch 100/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1493 - mse: 0.0309
# Epoch 101/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1493 - mse: 0.0309
# Epoch 102/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1492 - mse: 0.0309
# Epoch 103/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1492 - mse: 0.0309
# Epoch 104/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1491 - mse: 0.0309
# Epoch 105/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1491 - mse: 0.0308
# Epoch 106/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1490 - mse: 0.0308
# Epoch 107/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1490 - mse: 0.0308
# Epoch 108/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1489 - mse: 0.0308
# Epoch 109/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1489 - mse: 0.0308
# Epoch 110/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1488 - mse: 0.0308
# Epoch 111/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1488 - mse: 0.0307
# Epoch 112/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1487 - mse: 0.0307
# Epoch 113/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1486 - mse: 0.0307
# Epoch 114/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1486 - mse: 0.0307
# Epoch 115/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1485 - mse: 0.0307
# Epoch 116/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1485 - mse: 0.0306
# Epoch 117/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1484 - mse: 0.0306
# Epoch 118/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1484 - mse: 0.0306
# Epoch 119/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1483 - mse: 0.0306
# Epoch 120/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1483 - mse: 0.0306
# Epoch 121/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1482 - mse: 0.0306
# Epoch 122/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1482 - mse: 0.0305
# Epoch 123/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1481 - mse: 0.0305
# Epoch 124/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1481 - mse: 0.0305
# Epoch 125/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1480 - mse: 0.0305
# Epoch 126/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1480 - mse: 0.0305
# Epoch 127/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1479 - mse: 0.0305
# Epoch 128/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1479 - mse: 0.0304
# Epoch 129/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1478 - mse: 0.0304
# Epoch 130/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1478 - mse: 0.0304
# Epoch 131/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1477 - mse: 0.0304
# Epoch 132/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1477 - mse: 0.0304
# Epoch 133/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1476 - mse: 0.0303
# Epoch 134/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1475 - mse: 0.0303
# Epoch 135/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1475 - mse: 0.0303
# Epoch 136/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1474 - mse: 0.0303
# Epoch 137/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1474 - mse: 0.0303
# Epoch 138/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1473 - mse: 0.0303
# Epoch 139/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1473 - mse: 0.0302
# Epoch 140/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1472 - mse: 0.0302
# Epoch 141/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1472 - mse: 0.0302
# Epoch 142/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1471 - mse: 0.0302
# Epoch 143/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1471 - mse: 0.0302
# Epoch 144/500
# 2/2 [==============================] - 0s 51ms/step - loss: 0.1470 - mse: 0.0302
# Epoch 145/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1470 - mse: 0.0301
# Epoch 146/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1469 - mse: 0.0301
# Epoch 147/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1469 - mse: 0.0301
# Epoch 148/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1468 - mse: 0.0301
# Epoch 149/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1467 - mse: 0.0301
# Epoch 150/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1467 - mse: 0.0300
# Epoch 151/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1466 - mse: 0.0300
# Epoch 152/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1466 - mse: 0.0300
# Epoch 153/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1465 - mse: 0.0300
# Epoch 154/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1465 - mse: 0.0300
# Epoch 155/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1464 - mse: 0.0300
# Epoch 156/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1464 - mse: 0.0299
# Epoch 157/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1463 - mse: 0.0299
# Epoch 158/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1463 - mse: 0.0299
# Epoch 159/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1462 - mse: 0.0299
# Epoch 160/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1461 - mse: 0.0299
# Epoch 161/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1461 - mse: 0.0299
# Epoch 162/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1460 - mse: 0.0298
# Epoch 163/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1460 - mse: 0.0298
# Epoch 164/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1459 - mse: 0.0298
# Epoch 165/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1459 - mse: 0.0298
# Epoch 166/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1458 - mse: 0.0298
# Epoch 167/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1458 - mse: 0.0298
# Epoch 168/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1457 - mse: 0.0297
# Epoch 169/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1457 - mse: 0.0297
# Epoch 170/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1456 - mse: 0.0297
# Epoch 171/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1455 - mse: 0.0297
# Epoch 172/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1455 - mse: 0.0297
# Epoch 173/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1454 - mse: 0.0297
# Epoch 174/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1454 - mse: 0.0296
# Epoch 175/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1453 - mse: 0.0296
# Epoch 176/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1453 - mse: 0.0296
# Epoch 177/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1452 - mse: 0.0296
# Epoch 178/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1452 - mse: 0.0296
# Epoch 179/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1451 - mse: 0.0296
# Epoch 180/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1450 - mse: 0.0295
# Epoch 181/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1450 - mse: 0.0295
# Epoch 182/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1449 - mse: 0.0295
# Epoch 183/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1449 - mse: 0.0295
# Epoch 184/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1448 - mse: 0.0295
# Epoch 185/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1448 - mse: 0.0295
# Epoch 186/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1447 - mse: 0.0294
# Epoch 187/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1447 - mse: 0.0294
# Epoch 188/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1446 - mse: 0.0294
# Epoch 189/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1445 - mse: 0.0294
# Epoch 190/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1445 - mse: 0.0294
# Epoch 191/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1444 - mse: 0.0294
# Epoch 192/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1444 - mse: 0.0293
# Epoch 193/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1443 - mse: 0.0293
# Epoch 194/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1443 - mse: 0.0293
# Epoch 195/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1442 - mse: 0.0293
# Epoch 196/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1442 - mse: 0.0293
# Epoch 197/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1441 - mse: 0.0293
# Epoch 198/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1440 - mse: 0.0293
# Epoch 199/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1440 - mse: 0.0292
# Epoch 200/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1439 - mse: 0.0292
# Epoch 201/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1439 - mse: 0.0292
# Epoch 202/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1438 - mse: 0.0292
# Epoch 203/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1438 - mse: 0.0292
# Epoch 204/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1437 - mse: 0.0292
# Epoch 205/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1436 - mse: 0.0291
# Epoch 206/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1436 - mse: 0.0291
# Epoch 207/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1435 - mse: 0.0291
# Epoch 208/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1435 - mse: 0.0291
# Epoch 209/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1434 - mse: 0.0291
# Epoch 210/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1434 - mse: 0.0291
# Epoch 211/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1433 - mse: 0.0290
# Epoch 212/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1433 - mse: 0.0290
# Epoch 213/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1432 - mse: 0.0290
# Epoch 214/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1431 - mse: 0.0290
# Epoch 215/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1431 - mse: 0.0290
# Epoch 216/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1430 - mse: 0.0290
# Epoch 217/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1430 - mse: 0.0290
# Epoch 218/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1429 - mse: 0.0289
# Epoch 219/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1429 - mse: 0.0289
# Epoch 220/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1428 - mse: 0.0289
# Epoch 221/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1427 - mse: 0.0289
# Epoch 222/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1427 - mse: 0.0289
# Epoch 223/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1426 - mse: 0.0289
# Epoch 224/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1426 - mse: 0.0288
# Epoch 225/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1425 - mse: 0.0288
# Epoch 226/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1425 - mse: 0.0288
# Epoch 227/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1424 - mse: 0.0288
# Epoch 228/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1423 - mse: 0.0288
# Epoch 229/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1423 - mse: 0.0288
# Epoch 230/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1422 - mse: 0.0288
# Epoch 231/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1422 - mse: 0.0287
# Epoch 232/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1421 - mse: 0.0287
# Epoch 233/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1421 - mse: 0.0287
# Epoch 234/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1420 - mse: 0.0287
# Epoch 235/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1419 - mse: 0.0287
# Epoch 236/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1419 - mse: 0.0287
# Epoch 237/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1418 - mse: 0.0287
# Epoch 238/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1418 - mse: 0.0286
# Epoch 239/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1417 - mse: 0.0286
# Epoch 240/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1416 - mse: 0.0286
# Epoch 241/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1416 - mse: 0.0286
# Epoch 242/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1415 - mse: 0.0286
# Epoch 243/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1415 - mse: 0.0286
# Epoch 244/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1414 - mse: 0.0286
# Epoch 245/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1413 - mse: 0.0286
# Epoch 246/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1413 - mse: 0.0285
# Epoch 247/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1412 - mse: 0.0285
# Epoch 248/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1412 - mse: 0.0285
# Epoch 249/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1411 - mse: 0.0285
# Epoch 250/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1410 - mse: 0.0285
# Epoch 251/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1410 - mse: 0.0285
# Epoch 252/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1409 - mse: 0.0285
# Epoch 253/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1409 - mse: 0.0285
# Epoch 254/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1408 - mse: 0.0284
# Epoch 255/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1407 - mse: 0.0284
# Epoch 256/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1407 - mse: 0.0284
# Epoch 257/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1406 - mse: 0.0284
# Epoch 258/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1406 - mse: 0.0284
# Epoch 259/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1405 - mse: 0.0284
# Epoch 260/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1404 - mse: 0.0284
# Epoch 261/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1404 - mse: 0.0284
# Epoch 262/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1403 - mse: 0.0283
# Epoch 263/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1403 - mse: 0.0283
# Epoch 264/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1402 - mse: 0.0283
# Epoch 265/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1402 - mse: 0.0283
# Epoch 266/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1401 - mse: 0.0283
# Epoch 267/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1400 - mse: 0.0283
# Epoch 268/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1400 - mse: 0.0283
# Epoch 269/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1399 - mse: 0.0282
# Epoch 270/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1399 - mse: 0.0282
# Epoch 271/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1398 - mse: 0.0282
# Epoch 272/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1397 - mse: 0.0282
# Epoch 273/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1397 - mse: 0.0282
# Epoch 274/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1396 - mse: 0.0282
# Epoch 275/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1395 - mse: 0.0282
# Epoch 276/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1395 - mse: 0.0281
# Epoch 277/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1394 - mse: 0.0281
# Epoch 278/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1394 - mse: 0.0281
# Epoch 279/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1393 - mse: 0.0281
# Epoch 280/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1392 - mse: 0.0281
# Epoch 281/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1392 - mse: 0.0281
# Epoch 282/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1391 - mse: 0.0281
# Epoch 283/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1391 - mse: 0.0280
# Epoch 284/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1390 - mse: 0.0280
# Epoch 285/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1390 - mse: 0.0280
# Epoch 286/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1389 - mse: 0.0280
# Epoch 287/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1388 - mse: 0.0280
# Epoch 288/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1388 - mse: 0.0280
# Epoch 289/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1387 - mse: 0.0279
# Epoch 290/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1387 - mse: 0.0279
# Epoch 291/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1386 - mse: 0.0279
# Epoch 292/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1385 - mse: 0.0279
# Epoch 293/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1385 - mse: 0.0279
# Epoch 294/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1384 - mse: 0.0279
# Epoch 295/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1384 - mse: 0.0279
# Epoch 296/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1383 - mse: 0.0279
# Epoch 297/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1382 - mse: 0.0278
# Epoch 298/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1382 - mse: 0.0278
# Epoch 299/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1381 - mse: 0.0278
# Epoch 300/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1381 - mse: 0.0278
# Epoch 301/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1380 - mse: 0.0278
# Epoch 302/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1380 - mse: 0.0278
# Epoch 303/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1379 - mse: 0.0278
# Epoch 304/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1378 - mse: 0.0277
# Epoch 305/500
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1378 - mse: 0.0277
# Epoch 306/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1377 - mse: 0.0277
# Epoch 307/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1377 - mse: 0.0277
# Epoch 308/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1376 - mse: 0.0277
# Epoch 309/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1375 - mse: 0.0277
# Epoch 310/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1375 - mse: 0.0277
# Epoch 311/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1374 - mse: 0.0277
# Epoch 312/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1374 - mse: 0.0276
# Epoch 313/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1373 - mse: 0.0276
# Epoch 314/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1372 - mse: 0.0276
# Epoch 315/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1372 - mse: 0.0276
# Epoch 316/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1371 - mse: 0.0276
# Epoch 317/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1371 - mse: 0.0276
# Epoch 318/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1370 - mse: 0.0276
# Epoch 319/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1369 - mse: 0.0276
# Epoch 320/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1369 - mse: 0.0275
# Epoch 321/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1368 - mse: 0.0275
# Epoch 322/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1368 - mse: 0.0275
# Epoch 323/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1367 - mse: 0.0275
# Epoch 324/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1366 - mse: 0.0275
# Epoch 325/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1366 - mse: 0.0275
# Epoch 326/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1365 - mse: 0.0275
# Epoch 327/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1365 - mse: 0.0275
# Epoch 328/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1364 - mse: 0.0274
# Epoch 329/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1363 - mse: 0.0274
# Epoch 330/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1363 - mse: 0.0274
# Epoch 331/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1362 - mse: 0.0274
# Epoch 332/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1362 - mse: 0.0274
# Epoch 333/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1361 - mse: 0.0274
# Epoch 334/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1361 - mse: 0.0273
# Epoch 335/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1360 - mse: 0.0273
# Epoch 336/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1359 - mse: 0.0273
# Epoch 337/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1359 - mse: 0.0273
# Epoch 338/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1358 - mse: 0.0273
# Epoch 339/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1358 - mse: 0.0273
# Epoch 340/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1357 - mse: 0.0273
# Epoch 341/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1356 - mse: 0.0273
# Epoch 342/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1356 - mse: 0.0272
# Epoch 343/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1355 - mse: 0.0272
# Epoch 344/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1355 - mse: 0.0272
# Epoch 345/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1354 - mse: 0.0272
# Epoch 346/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1354 - mse: 0.0272
# Epoch 347/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1353 - mse: 0.0272
# Epoch 348/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1352 - mse: 0.0272
# Epoch 349/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1352 - mse: 0.0272
# Epoch 350/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1351 - mse: 0.0271
# Epoch 351/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1351 - mse: 0.0271
# Epoch 352/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1350 - mse: 0.0271
# Epoch 353/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1349 - mse: 0.0271
# Epoch 354/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1349 - mse: 0.0271
# Epoch 355/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1348 - mse: 0.0271
# Epoch 356/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1348 - mse: 0.0271
# Epoch 357/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1347 - mse: 0.0271
# Epoch 358/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1347 - mse: 0.0270
# Epoch 359/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1346 - mse: 0.0270
# Epoch 360/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1345 - mse: 0.0270
# Epoch 361/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1345 - mse: 0.0270
# Epoch 362/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1344 - mse: 0.0270
# Epoch 363/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1344 - mse: 0.0270
# Epoch 364/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1343 - mse: 0.0270
# Epoch 365/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1343 - mse: 0.0270
# Epoch 366/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1342 - mse: 0.0270
# Epoch 367/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1341 - mse: 0.0270
# Epoch 368/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1341 - mse: 0.0269
# Epoch 369/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1340 - mse: 0.0269
# Epoch 370/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1340 - mse: 0.0269
# Epoch 371/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1339 - mse: 0.0269
# Epoch 372/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1339 - mse: 0.0269
# Epoch 373/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1338 - mse: 0.0269
# Epoch 374/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1337 - mse: 0.0269
# Epoch 375/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1337 - mse: 0.0269
# Epoch 376/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1336 - mse: 0.0268
# Epoch 377/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1336 - mse: 0.0268
# Epoch 378/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1335 - mse: 0.0268
# Epoch 379/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1334 - mse: 0.0268
# Epoch 380/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1334 - mse: 0.0268
# Epoch 381/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1333 - mse: 0.0268
# Epoch 382/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1333 - mse: 0.0268
# Epoch 383/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1332 - mse: 0.0268
# Epoch 384/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1332 - mse: 0.0268
# Epoch 385/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1331 - mse: 0.0268
# Epoch 386/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1330 - mse: 0.0268
# Epoch 387/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1330 - mse: 0.0268
# Epoch 388/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1329 - mse: 0.0268
# Epoch 389/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1329 - mse: 0.0268
# Epoch 390/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1328 - mse: 0.0267
# Epoch 391/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1328 - mse: 0.0267
# Epoch 392/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1327 - mse: 0.0267
# Epoch 393/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1327 - mse: 0.0267
# Epoch 394/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1326 - mse: 0.0267
# Epoch 395/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1325 - mse: 0.0267
# Epoch 396/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1325 - mse: 0.0267
# Epoch 397/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1324 - mse: 0.0267
# Epoch 398/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1324 - mse: 0.0266
# Epoch 399/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1323 - mse: 0.0266
# Epoch 400/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1323 - mse: 0.0266
# Epoch 401/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1322 - mse: 0.0266
# Epoch 402/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1321 - mse: 0.0266
# Epoch 403/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1321 - mse: 0.0266
# Epoch 404/500
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1320 - mse: 0.0266
# Epoch 405/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1320 - mse: 0.0266
# Epoch 406/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1319 - mse: 0.0266
# Epoch 407/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1319 - mse: 0.0266
# Epoch 408/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1318 - mse: 0.0266
# Epoch 409/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1317 - mse: 0.0266
# Epoch 410/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1317 - mse: 0.0266
# Epoch 411/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1316 - mse: 0.0265
# Epoch 412/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1316 - mse: 0.0265
# Epoch 413/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1315 - mse: 0.0265
# Epoch 414/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1315 - mse: 0.0265
# Epoch 415/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1314 - mse: 0.0265
# Epoch 416/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1314 - mse: 0.0265
# Epoch 417/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1313 - mse: 0.0265
# Epoch 418/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1312 - mse: 0.0265
# Epoch 419/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1312 - mse: 0.0265
# Epoch 420/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1311 - mse: 0.0265
# Epoch 421/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1311 - mse: 0.0264
# Epoch 422/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1310 - mse: 0.0264
# Epoch 423/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1310 - mse: 0.0264
# Epoch 424/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1309 - mse: 0.0264
# Epoch 425/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1309 - mse: 0.0264
# Epoch 426/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1308 - mse: 0.0264
# Epoch 427/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1307 - mse: 0.0264
# Epoch 428/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1307 - mse: 0.0264
# Epoch 429/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1306 - mse: 0.0264
# Epoch 430/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1306 - mse: 0.0264
# Epoch 431/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1305 - mse: 0.0264
# Epoch 432/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1305 - mse: 0.0263
# Epoch 433/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1304 - mse: 0.0263
# Epoch 434/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1303 - mse: 0.0263
# Epoch 435/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1303 - mse: 0.0263
# Epoch 436/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1302 - mse: 0.0263
# Epoch 437/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1302 - mse: 0.0263
# Epoch 438/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1301 - mse: 0.0263
# Epoch 439/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1301 - mse: 0.0262
# Epoch 440/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1300 - mse: 0.0262
# Epoch 441/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1300 - mse: 0.0262
# Epoch 442/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1299 - mse: 0.0262
# Epoch 443/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1299 - mse: 0.0262
# Epoch 444/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1298 - mse: 0.0262
# Epoch 445/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1298 - mse: 0.0262
# Epoch 446/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1297 - mse: 0.0262
# Epoch 447/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1297 - mse: 0.0262
# Epoch 448/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1296 - mse: 0.0262
# Epoch 449/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1295 - mse: 0.0262
# Epoch 450/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1295 - mse: 0.0262
# Epoch 451/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1294 - mse: 0.0262
# Epoch 452/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1294 - mse: 0.0262
# Epoch 453/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1293 - mse: 0.0262
# Epoch 454/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1293 - mse: 0.0262
# Epoch 455/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1292 - mse: 0.0262
# Epoch 456/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1292 - mse: 0.0262
# Epoch 457/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1291 - mse: 0.0261
# Epoch 458/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1291 - mse: 0.0261
# Epoch 459/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1290 - mse: 0.0261
# Epoch 460/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1289 - mse: 0.0261
# Epoch 461/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1289 - mse: 0.0261
# Epoch 462/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1288 - mse: 0.0261
# Epoch 463/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1288 - mse: 0.0261
# Epoch 464/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1287 - mse: 0.0261
# Epoch 465/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1287 - mse: 0.0261
# Epoch 466/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1286 - mse: 0.0261
# Epoch 467/500
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1286 - mse: 0.0261
# Epoch 468/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1285 - mse: 0.0261
# Epoch 469/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1285 - mse: 0.0261
# Epoch 470/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1284 - mse: 0.0261
# Epoch 471/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1284 - mse: 0.0261
# Epoch 472/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1283 - mse: 0.0261
# Epoch 473/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1283 - mse: 0.0261
# Epoch 474/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1282 - mse: 0.0261
# Epoch 475/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1281 - mse: 0.0261
# Epoch 476/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1281 - mse: 0.0260
# Epoch 477/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1280 - mse: 0.0260
# Epoch 478/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1280 - mse: 0.0260
# Epoch 479/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1279 - mse: 0.0260
# Epoch 480/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1279 - mse: 0.0260
# Epoch 481/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1278 - mse: 0.0260
# Epoch 482/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1278 - mse: 0.0260
# Epoch 483/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1277 - mse: 0.0260
# Epoch 484/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1277 - mse: 0.0260
# Epoch 485/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1276 - mse: 0.0260
# Epoch 486/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1276 - mse: 0.0259
# Epoch 487/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1275 - mse: 0.0259
# Epoch 488/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1275 - mse: 0.0259
# Epoch 489/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1274 - mse: 0.0259
# Epoch 490/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1274 - mse: 0.0259
# Epoch 491/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1273 - mse: 0.0259
# Epoch 492/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1273 - mse: 0.0259
# Epoch 493/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1272 - mse: 0.0258
# Epoch 494/500
# 2/2 [==============================] - 0s 18ms/step - loss: 0.1272 - mse: 0.0258
# Epoch 495/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1271 - mse: 0.0258
# Epoch 496/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1271 - mse: 0.0258
# Epoch 497/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1270 - mse: 0.0258
# Epoch 498/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1270 - mse: 0.0258
# Epoch 499/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1269 - mse: 0.0258
# Epoch 500/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1269 - mse: 0.0258

# %%
Y_p = model.predict(X)
Y_p = Y_p.reshape((h,w,c))
im = plt.imshow(Y_p[...,0], cmap='gray')
plt.show()
# Out:
#  1/75 [..............................] - ETA: 1s
# 75/75 [==============================] - 0s 965us/step

# %%
fig, axs = plt.subplots(1, 2, figsize=(10,5))
axs[0].plot(hist.epoch, hist.history['loss'])
axs[0].set_title('loss')
axs[1].plot(hist.epoch, hist.history['mse'])
axs[1].set_title('mse')
plt.show()

# %% [markdown]
# What is actually happening here? We fit an image with an $\mathbb{R}^2 \rightarrow \mathbb{R}$ funcion.

# %%
x = X[:,0].reshape((h,w))
y = X[:,1].reshape((h,w))
z = Y.reshape((h,w))
zp = Y_p.reshape((h,w))

ds = 2
x = subsample(x, ds)
y =-subsample(y, ds)
z = subsample(z, ds)
zp = subsample(zp, ds)

#surf = ax.plot_surface(x,y,z, cmap='coolwarm', linewidth=0, antialiased=False, alpha=0.3)
#surf = ax.plot_surface(x,y,zp, cmap='coolwarm', linewidth=0, antialiased=False, alpha=0.5)
#plt.show()

fig = go.Figure(data=[go.Surface(z=zp, x=x, y=y)])
fig.update_layout(autosize=False,
                  width=500, height=500,
                  margin=dict(l=65, r=50, b=65, t=90))
fig.show()
# Out:
# /var/folders/k1/tlc1r2s97gj6r2x8xm2cchlh0000gn/T/ipykernel_51371/2121674518.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   newimg = img.resize((w, h), Image.ANTIALIAS)

# %% [markdown]
# Let's try the same with an RGB image:

# %%
image = subsample(image_big, 15)
plt.imshow(image)
plt.show()
# Out:
# /var/folders/k1/tlc1r2s97gj6r2x8xm2cchlh0000gn/T/ipykernel_51371/2121674518.py:7: DeprecationWarning:
#
# ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.

# %%
h, w, c = image.shape
X = np.meshgrid(np.linspace(0, 1, w), np.linspace(0, 1, h))
X = np.stack(X, axis=-1).reshape((-1, 2))

Y = image.reshape((-1, c))
X.shape, Y.shape
# Out:
# ((2400, 2), (2400, 3))

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(2,)),
  tf.keras.layers.Dense(c, activation='sigmoid'),
])
model.compile(optimizer='adam',
              loss='mae',
              metrics=['mse'])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_3 (Flatten)         (None, 2)                 0
#
#  dense_5 (Dense)             (None, 3)                 9
#
# =================================================================
# Total params: 9 (36.00 Byte)
# Trainable params: 9 (36.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# But now we will save images during the course of training, at first after 2, then 4, 8, 16, etc epochs.
# (**Remember**: call to `model.fit` does NOT reinitialize trainable variables. Every time it continues from the previous state):

# %%
class saving_pred(tf.keras.callbacks.Callback):
  def __init__(self, n_ep_pow):
    self.ims = []
    self.save_epochs = [0]+[2**i for i in range(n_ep_pow)]

  def on_epoch_end(self, epoch, logs=None):
    if epoch in self.save_epochs:
        Y_p = model.predict(X)
        Y_p = Y_p.reshape((h, w, c))
        self.ims.append(Y_p)

# %%
n_ep_pow = 11
n_ep = 2**n_ep_pow+1

ims_callback = saving_pred(n_ep_pow)
hist = model.fit(X, Y, epochs=n_ep, batch_size=1*2048, verbose=0, callbacks=[ims_callback])

plt.plot(hist.epoch, hist.history['loss'])
plt.show()
# Out:
# 75/75 [==============================] - 0s 996us/step
# 75/75 [==============================] - 0s 1ms/step
# 75/75 [==============================] - 0s 955us/step
# 75/75 [==============================] - 0s 870us/step
# 75/75 [==============================] - 0s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# 75/75 [==============================] - 0s 915us/step
# 75/75 [==============================] - 0s 943us/step
# 75/75 [==============================] - 0s 978us/step
# 75/75 [==============================] - 0s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# 75/75 [==============================] - 0s 883us/step

# %%
# %%capture

ims = ims_callback.ims
fig = plt.figure()
im = plt.imshow(ims[0])

def animate(i):
    img = ims[i]
    im.set_data(img)
    return im

ani = animation.FuncAnimation(fig, animate, frames=len(ims))

# %%
ani
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgfd8e00fd35684b889cd5a7ea188980eb">
#   <div class="anim-controls">
#     <input id="_anim_sliderfd8e00fd35684b889cd5a7ea188980eb" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animfd8e00fd35684b889cd5a7ea188980eb.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animfd8e00fd35684b889cd5a7ea188980eb.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animfd8e00fd35684b889cd5a7ea188980eb.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animfd8e00fd35684b889cd5a7ea188980eb.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animfd8e00fd35684b889cd5a7ea188980eb.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animfd8e00fd35684b889cd5a7ea188980eb.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animfd8e00fd35684b889cd5a7ea188980eb.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animfd8e00fd35684b889cd5a7ea188980eb.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animfd8e00fd35684b889cd5a7ea188980eb.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animfd8e00fd35684b889cd5a7ea188980eb.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectfd8e00fd35684b889cd5a7ea188980eb"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_fd8e00fd35684b889cd5a7ea188980eb"
#              >
#       <label for="_anim_radio1_fd8e00fd35684b889cd5a7ea188980eb">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_fd8e00fd35684b889cd5a7ea188980eb"
#              checked>
#       <label for="_anim_radio2_fd8e00fd35684b889cd5a7ea188980eb">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_fd8e00fd35684b889cd5a7ea188980eb"
#              >
#       <label for="_anim_radio3_fd8e00fd35684b889cd5a7ea188980eb">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgfd8e00fd35684b889cd5a7ea188980eb";
#     var slider_id = "_anim_sliderfd8e00fd35684b889cd5a7ea188980eb";
#     var loop_select_id = "_anim_loop_selectfd8e00fd35684b889cd5a7ea188980eb";
#     var frames = new Array(12);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjcuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/bCgiHAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAAuGUlEQ

# %% [markdown]
# While the colors properly represent the target image, our model still poses very limited capacity, allowing it to effectively represent only 3 boundaries.
#
# Let's upscale our model:

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(2,)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(8, activation='relu'),
  tf.keras.layers.Dense(c, activation='sigmoid'),
])
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.005), # optimizer='adam',
              loss='mae',
              metrics=['mse'])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_4 (Flatten)         (None, 2)                 0
#
#  dense_6 (Dense)             (None, 128)               384
#
#  dense_7 (Dense)             (None, 8)                 1032
#
#  dense_8 (Dense)             (None, 3)                 27
#
# =================================================================
# Total params: 1443 (5.64 KB)
# Trainable params: 1443 (5.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
X.shape
# Out:
# (2400, 2)

# %%
n_ep_pow = 13
n_ep = 2**n_ep_pow+1

ims_callback = saving_pred(n_ep_pow)
hist = model.fit(X, Y, epochs=n_ep, batch_size=1*2048, verbose=0, callbacks=[ims_callback])

plt.plot(hist.epoch, hist.history['loss'])
plt.show()
# Out:
# 75/75 [==============================] - 0s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# 75/75 [==============================] - 0s 899us/step
# 75/75 [==============================] - 0s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# 75/75 [==============================] - 0s 962us/step
# 75/75 [==============================] - 0s 944us/step
# 75/75 [==============================] - 0s 983us/step
# 75/75 [==============================] - 0s 905us/step
# 75/75 [==============================] - 0s 898us/step
# 75/75 [==============================] - 0s 968us/step

# %%
# %%capture

ims = ims_callback.ims
fig = plt.figure()
im = plt.imshow(ims[0])

def animate(i):
    img = ims[i]
    im.set_data(img)
    return im

ani = animation.FuncAnimation(fig, animate, frames=len(ims))

# %%
ani
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgec6121a9602b44cb83a5efac41378e26">
#   <div class="anim-controls">
#     <input id="_anim_sliderec6121a9602b44cb83a5efac41378e26" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animec6121a9602b44cb83a5efac41378e26.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animec6121a9602b44cb83a5efac41378e26.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animec6121a9602b44cb83a5efac41378e26.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animec6121a9602b44cb83a5efac41378e26.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animec6121a9602b44cb83a5efac41378e26.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animec6121a9602b44cb83a5efac41378e26.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animec6121a9602b44cb83a5efac41378e26.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animec6121a9602b44cb83a5efac41378e26.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animec6121a9602b44cb83a5efac41378e26.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animec6121a9602b44cb83a5efac41378e26.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectec6121a9602b44cb83a5efac41378e26"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_ec6121a9602b44cb83a5efac41378e26"
#              >
#       <label for="_anim_radio1_ec6121a9602b44cb83a5efac41378e26">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_ec6121a9602b44cb83a5efac41378e26"
#              checked>
#       <label for="_anim_radio2_ec6121a9602b44cb83a5efac41378e26">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_ec6121a9602b44cb83a5efac41378e26"
#              >
#       <label for="_anim_radio3_ec6121a9602b44cb83a5efac41378e26">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgec6121a9602b44cb83a5efac41378e26";
#     var slider_id = "_anim_sliderec6121a9602b44cb83a5efac41378e26";
#     var loop_select_id = "_anim_loop_selectec6121a9602b44cb83a5efac41378e26";
#     var frames = new Array(14);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjcuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/bCgiHAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAAnS0lEQ

# %% [markdown]
# We can also now render the fitted image at any resolution, by evaluating values in between of the original pixels:

# %%
scale = 30
w_rend = w * scale
h_rend = h * scale
X_rend = np.meshgrid(np.linspace(0, 1, w_rend), np.linspace(0, 1, h_rend))
X_rend = np.stack(X_rend, axis=-1).reshape((-1, 2))

Y_rend = model.predict(X_rend)
Y_rend = Y_rend.reshape((h_rend, w_rend, c))

plt.imshow(Y_rend)
# Out:
# 67500/67500 [==============================] - 57s 840us/step

# %%
plt.imshow(image_big)

# %%
plt.imshow(image)

# %% [markdown]
# ## EXERCISE 1. Regression on an image with Neural Network.

# %% [markdown]
# Load some image, downscale to a similar resolution, and train a deeper model, for example 5 layers, more parameters in widest layers.

# %%
# 1. Load your image

# 2. build a deeper model

# 3. inspect the evolution

# %% [markdown]
# # 4. Classification of the F-MNIST dataset with neural network

# %% [markdown]
# ## 0. Load data

# %% [markdown]
# We will create a model for classification of the F-MNIST dataset that we go acquainted with in previous sessions. We will normalize the inputs to have values $\in[0,1]$:

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train = x_train/255 #divide by number of pixels to normalize values to lie between 0 and 1
x_test = x_test/255

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# ## 1. Building a neural network

# %%
print(x_train[0].shape)
# Out:
# (28, 28)

# %% [markdown]
# The size of each image sample $-\; 28\times28\text{ pixels}\;-\;$ defines the input size for our neural network. Network's output - probabilities of belonging to each of the 10 classes.

# %% [markdown]
# The following creates a 'model'. It is an object containing the neural network model itself - a simple 3-layer fully connected neural network, optimization parameters, as well as the interface for model training.

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# %% [markdown]
# Model summary provides information about the model's layers and trainable parameters

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_5 (Flatten)         (None, 784)               0
#
#  dense_9 (Dense)             (None, 10)                7850
#
# =================================================================
# Total params: 7850 (30.66 KB)
# Trainable params: 7850 (30.66 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# The `fit` function is the interface for model training.
# Here one can specify training and validation datasets, minibatch size, and the number of training epochs.
#
# Here during training we also save the trained models checkpoints after each epoch of training.

# %%
save_path = 'save/mnist_{epoch}.ckpt'
save_callback = tf.keras.callbacks.ModelCheckpoint(filepath=save_path, save_weights_only=True)

hist = model.fit(x=x_train, y=y_train,
                 epochs=50, batch_size=128,
                 validation_data=(x_test, y_test),
                 callbacks=[save_callback])
# Out:
# Epoch 1/50
# 469/469 [==============================] - 2s 3ms/step - loss: 0.7644 - accuracy: 0.7469 - val_loss: 0.5878 - val_accuracy: 0.8065
# Epoch 2/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.5213 - accuracy: 0.8262 - val_loss: 0.5204 - val_accuracy: 0.8245
# Epoch 3/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4771 - accuracy: 0.8396 - val_loss: 0.4990 - val_accuracy: 0.8265
# Epoch 4/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4547 - accuracy: 0.8467 - val_loss: 0.4811 - val_accuracy: 0.8346
# Epoch 5/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4395 - accuracy: 0.8504 - val_loss: 0.4702 - val_accuracy: 0.8373
# Epoch 6/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4298 - accuracy: 0.8536 - val_loss: 0.4621 - val_accuracy: 0.8388
# Epoch 7/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4218 - accuracy: 0.8553 - val_loss: 0.4608 - val_accuracy: 0.8392
# Epoch 8/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4164 - accuracy: 0.8569 - val_loss: 0.4564 - val_accuracy: 0.8392
# Epoch 9/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4103 - accuracy: 0.8590 - val_loss: 0.4518 - val_accuracy: 0.8425
# Epoch 10/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4056 - accuracy: 0.8611 - val_loss: 0.4473 - val_accuracy: 0.8448
# Epoch 11/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4022 - accuracy: 0.8622 - val_loss: 0.4488 - val_accuracy: 0.8434
# Epoch 12/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3998 - accuracy: 0.8636 - val_loss: 0.4460 - val_accuracy: 0.8450
# Epoch 13/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3974 - accuracy: 0.8626 - val_loss: 0.4429 - val_accuracy: 0.8454
# Epoch 14/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3939 - accuracy: 0.8644 - val_loss: 0.4459 - val_accuracy: 0.8434
# Epoch 15/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3913 - accuracy: 0.8650 - val_loss: 0.4389 - val_accuracy: 0.8486
# Epoch 16/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3898 - accuracy: 0.8658 - val_loss: 0.4473 - val_accuracy: 0.8427
# Epoch 17/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3877 - accuracy: 0.8661 - val_loss: 0.4447 - val_accuracy: 0.8445
# Epoch 18/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3872 - accuracy: 0.8655 - val_loss: 0.4413 - val_accuracy: 0.8455
# Epoch 19/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3850 - accuracy: 0.8673 - val_loss: 0.4453 - val_accuracy: 0.8435
# Epoch 20/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3829 - accuracy: 0.8679 - val_loss: 0.4421 - val_accuracy: 0.8460
# Epoch 21/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3824 - accuracy: 0.8673 - val_loss: 0.4474 - val_accuracy: 0.8455
# Epoch 22/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3806 - accuracy: 0.8687 - val_loss: 0.4369 - val_accuracy: 0.8462
# Epoch 23/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3805 - accuracy: 0.8681 - val_loss: 0.4382 - val_accuracy: 0.8462
# Epoch 24/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3790 - accuracy: 0.8684 - val_loss: 0.4383 - val_accuracy: 0.8468
# Epoch 25/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3786 - accuracy: 0.8688 - val_loss: 0.4377 - val_accuracy: 0.8467
# Epoch 26/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3768 - accuracy: 0.8695 - val_loss: 0.4428 - val_accuracy: 0.8444
# Epoch 27/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3759 - accuracy: 0.8687 - val_loss: 0.4406 - val_accuracy: 0.8468
# Epoch 28/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3745 - accuracy: 0.8701 - val_loss: 0.4378 - val_accuracy: 0.8474
# Epoch 29/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3741 - accuracy: 0.8692 - val_loss: 0.4388 - val_accuracy: 0.8459
# Epoch 30/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3727 - accuracy: 0.8694 - val_loss: 0.4370 - val_accuracy: 0.8481
# Epoch 31/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3736 - accuracy: 0.8686 - val_loss: 0.4394 - val_accuracy: 0.8464
# Epoch 32/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3716 - accuracy: 0.8704 - val_loss: 0.4426 - val_accuracy: 0.8459
# Epoch 33/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3721 - accuracy: 0.8698 - val_loss: 0.4353 - val_accuracy: 0.8473
# Epoch 34/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3699 - accuracy: 0.8709 - val_loss: 0.4399 - val_accuracy: 0.8463
# Epoch 35/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3699 - accuracy: 0.8698 - val_loss: 0.4396 - val_accuracy: 0.8474
# Epoch 36/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3691 - accuracy: 0.8716 - val_loss: 0.4378 - val_accuracy: 0.8464
# Epoch 37/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3688 - accuracy: 0.8710 - val_loss: 0.4378 - val_accuracy: 0.8483
# Epoch 38/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3682 - accuracy: 0.8710 - val_loss: 0.4428 - val_accuracy: 0.8455
# Epoch 39/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3683 - accuracy: 0.8711 - val_loss: 0.4384 - val_accuracy: 0.8483
# Epoch 40/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3671 - accuracy: 0.8722 - val_loss: 0.4400 - val_accuracy: 0.8462
# Epoch 41/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3665 - accuracy: 0.8717 - val_loss: 0.4366 - val_accuracy: 0.8474
# Epoch 42/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3662 - accuracy: 0.8722 - val_loss: 0.4390 - val_accuracy: 0.8466
# Epoch 43/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3663 - accuracy: 0.8716 - val_loss: 0.4371 - val_accuracy: 0.8485
# Epoch 44/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3652 - accuracy: 0.8723 - val_loss: 0.4440 - val_accuracy: 0.8457
# Epoch 45/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3638 - accuracy: 0.8731 - val_loss: 0.4387 - val_accuracy: 0.8484
# Epoch 46/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3639 - accuracy: 0.8727 - val_loss: 0.4391 - val_accuracy: 0.8464
# Epoch 47/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3649 - accuracy: 0.8723 - val_loss: 0.4377 - val_accuracy: 0.8477
# Epoch 48/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3640 - accuracy: 0.8718 - val_loss: 0.4404 - val_accuracy: 0.8476
# Epoch 49/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3631 - accuracy: 0.8728 - val_loss: 0.4376 - val_accuracy: 0.8475
# Epoch 50/50
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3622 - accuracy: 0.8728 - val_loss: 0.4392 - val_accuracy: 0.8473

# %%
fig, axs = plt.subplots(1, 2, figsize=(10,5))
axs[0].plot(hist.epoch, hist.history['loss'])
axs[0].plot(hist.epoch, hist.history['val_loss'])
axs[0].legend(('training loss', 'validation loss'), loc='lower right')
axs[1].plot(hist.epoch, hist.history['accuracy'])
axs[1].plot(hist.epoch, hist.history['val_accuracy'])

axs[1].legend(('training accuracy', 'validation accuracy'), loc='lower right')
plt.show()

# %% [markdown]
# Current model performance can be evaluated, e.g. on the test dataset:
#
# ---

# %%
model.evaluate(x_test,  y_test, verbose=2)
# Out:
# 313/313 - 0s - loss: 0.4392 - accuracy: 0.8473 - 322ms/epoch - 1ms/step
# [0.4392070174217224, 0.8472999930381775]

# %% [markdown]
# We can test trained model on an image:

# %%
im_id = 0
y_pred = model(x_test)

y_pred_most_probable = np.argmax(y_pred[im_id])
print('true lablel: ', y_test[im_id],
      '; predicted: ',  y_pred_most_probable,
      f'({class_names[y_pred_most_probable]})')
plt.imshow(x_test[im_id], cmap='gray');

# %% [markdown]
# As well as inspect on which samples does the model fail:

# %%
y_pred_most_probable_all = np.argmax(y_pred, axis=1)
wrong_pred_map = y_pred_most_probable_all!=y_test
wrong_pred_idx = np.arange(len(wrong_pred_map))[wrong_pred_map]

im_id = wrong_pred_idx[0]

y_pred_most_probable = y_pred_most_probable_all[im_id]
print('true lablel: ', y_test[im_id],
      f'({class_names[y_test[im_id]]})',
      '; predicted: ',  y_pred_most_probable,
      f'({class_names[y_pred_most_probable]})')
plt.imshow(x_test[im_id], cmap='gray');
plt.show()

# %% [markdown]
# ## 3. Loading trained model

# %%
model.load_weights('save/mnist_1.ckpt')
model.evaluate(x_test,  y_test, verbose=2)

model.load_weights('save/mnist_12.ckpt')
model.evaluate(x_test,  y_test, verbose=2)

model.load_weights('save/mnist_18.ckpt')
model.evaluate(x_test,  y_test, verbose=2)

# %% [markdown]
# ## 4. Inspecting trained variables

# %% [markdown]
# We can obtain the trained variables from model layers:

# %%
l = model.get_layer(index=1)
w, b = l.weights

w = w.numpy()
b = b.numpy()
print(w.shape, b.shape)
w = w.reshape((28,28,-1)).transpose((2, 0, 1))

# %% [markdown]
# Let's visualize first 10:

# %%
n = 10
fig, axs = plt.subplots(1, n, figsize=(4.1*n,4))
for i, wi in enumerate(w[:n]):
  axs[i].imshow(wi, cmap='gray')
  axs[i].set_title(class_names[i])
plt.show()

# %% [markdown]
# ## 6. Inspecting gradients

# %% [markdown]
# We can also evaluate the gradients of each output with respect to an input:

# %%
idx = 112
inp_v = x_train[idx:idx+1]  # use some image to compute gradients with respect to

inp = tf.constant(inp_v)  # create tf constant tensor
with tf.GradientTape() as tape:  # gradient tape for gradint evaluation
  tape.watch(inp)  # take inp as variable
  preds = model(inp) # evaluate model output

grads = tape.jacobian(preds, inp)  # evaluate d preds[i] / d inp[j]
print(grads.shape, '<- (Batch_preds, preds[i], Batch_inp, inp[y], inp[x])')
grads = grads.numpy()[0,:,0]
# Out:
# (1, 10, 1, 28, 28) <- (Batch_preds, preds[i], Batch_inp, inp[y], inp[x])

# %%
print('prediction:', np.argmax(preds[0]))
fig, axs = plt.subplots(1, 11, figsize=(4.1*11,4))
axs[0].imshow(inp_v[0])
axs[0].set_title('raw')
vmin,vmax = grads.min(), grads.max()
for i, g in enumerate(grads):
  axs[i+1].imshow(g, cmap='gray', vmin=vmin, vmax=vmax)
  axs[i+1].set_title(r'$\frac{\partial\;P(digit\,%d)}{\partial\;input}$' % i, fontdict={'size':16})
plt.show()
# Out:
# prediction: 6

# %% [markdown]
# ## EXERCISE 2: Train deeper network for F-MNIST classification

# %% [markdown]
# Make a deeper model, with wider layers. Remember to use the `'softmax'` activation in the last layer, as required for the classification task to encode pseudoprobabilities. In the other layers you could use `'relu'`.
#
# Try to achieve 90% accuracy.
# Does your model overfit?

# %%
# 1. create model
# 2. train the model
# 3. plot the loss and accuracy evolution during training
# 4. evaluate model in best point (before overfitting)

# %% [markdown]
# # 5. Extras and Q&A

# %% [markdown]
# <img src="https://github.com/neworldemancer/DSF5/raw/master/figures/cheatsheet.png" width="100%"/>

# %% [markdown]
# <img src="https://github.com/neworldemancer/DSF5/raw/master/figures/clusters.png" width="100%"/>
